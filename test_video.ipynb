# %% [markdown]
# ### Processing file

# %% [markdown]
# Importing libraries and functions

# %%
from ultralytics import YOLO
import functions

# %% [markdown]
# Selecting paths to files

# %%
model_path=r"files\best_def.pt"
mps_path=r"files\Eye_Gaze_def.csv"
vrs_path=r"files\VRS_def.vrs"

# %% [markdown]
# Loading of the object detection model

# %%
trained_model = YOLO(model_path)   #load the model weights

# %% [markdown]
# Processing of the video

# %%
functions.inference_video(vrs_path,mps_path,trained_model,allowed_classes=[0,1,2,3,4,5],conf=0.6,start_frame=580,stop_frame=1120)
# Out:
# 0: 640x640 (no detections), 240.2ms
# Speed: 17.6ms preprocess, 240.2ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 168.7ms
# Speed: 9.9ms preprocess, 168.7ms inference, 13.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 94.9ms
# Speed: 5.0ms preprocess, 94.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 85.0ms
# Speed: 7.4ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 90.6ms
# Speed: 6.0ms preprocess, 90.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 123.2ms
# Speed: 6.2ms preprocess, 123.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Brake_front, 1 Torx_8940, 92.1ms
# Speed: 6.5ms preprocess, 92.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
